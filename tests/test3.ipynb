# %% [markdown]
# Test details: we want to test the 146 questions and make it better and save it somewhere
#
# Author: Dhairya Kantawala

# %%
import sys
sys.path.append('..')
import functions

# %%
import pandas as pd
df = functions.get_vector_df('/Users/dhairya/cs projects/SusReach/data/BRSR202324.pdf')

# %%
functions.page_number_on_embd_df("section 135", df)
# Out:
# 7

# %%
template = pd.read_excel('/Users/dhairya/cs projects/SusReach/data/146 Question BRSR Template.xlsx', sheet_name=0, header=3)
col1 = '#Question Ref.'
col2 = 'Reporting Requirement'
col3 = 'Definitions'
col4 = 'Department'

# %%
template.index = template[col1]
template = template[[col2, col3, col4]]

# %%
template.to_csv('/Users/dhairya/cs projects/SusReach/data/146 Question BRSR Template.csv')
