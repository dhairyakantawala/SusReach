# %% [markdown]
# Test details: Make chatpgt functions to actully find solutions and run stuff around
#
# Author: Dhairya Kantawala

# %%
import pandas as pd
import sys
sys.path.append('..')
import functions
template = pd.read_csv('/Users/dhairya/cs projects/SusReach/data/test_data.csv', index_col=0)
file_path = '/Users/dhairya/cs projects/SusReach/data/BRSR202324.pdf'

# %%
page_df = functions.get_page_df(file_path)

# %%
for i in range(len(template)):
    template.loc[i, 'page_content'] = page_df['page_content'].iloc[int(template['page_number'].iloc[i])]

# %%
for i in range(len(template)):
    template.loc[i, 'prompt'] = f"You are a data extraction expert. Given the reporting requirement: '{template['Reporting Requirement'].iloc[i]}' and associated definitions: '{template['Definitions'].iloc[i]}', carefully analyze this BRSR report section: '{template['page_content'].iloc[i]}'. Extract ONLY the specific information requested. Format your response as follows:\n\n1. Use a single line of text\n2. Include only the extracted information without any explanation\n3. Separate multiple items with semicolons\n4. For numerical data, provide exact figures\n5. If information cannot be found, respond only with 'Information not available'\n\nBe precise and concise in your extraction."

# %%
from langchain_community.document_loaders import PyPDFLoader
import pandas as pd
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("OPENAI_API")
from openai import OpenAI
client = OpenAI(api_key=api_key)
import numpy as np
from numpy.linalg import norm

response = client.responses.create(
    model="gpt-4o-mini",
    input="Write a one-sentence bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# As the stars twinkled brightly above, Luna the unicorn danced gracefully through the enchanted forest, spreading her shimmering magic to help all the woodland creatures fall asleep in peace.

# %%
def get_answer(prompt):
    response = client.responses.create(
        model="gpt-4o-mini",
        input=prompt
    )
    return response.output_text

# %%
from tqdm import tqdm
for i in tqdm(range(len(template))):
    try:
        template.loc[i, "answer"] = get_answer(template['prompt'].iloc[i])
    except:
        template.loc[i, "answer"] = "Error caused NA"
# Out:
# 100%|██████████| 146/146 [06:32<00:00,  2.69s/it]

# %%
for i in range(len(template)):
    print("\nQuestion: "+ template['Reporting Requirement'].iloc[i], end="\nAnswer: ")
    print(template['answer'].iloc[i])
# Out:
# Question: Corporate Identity Number (CIN) of the Listed Entity
# Answer: Information not available
#
# Question: Name of the Listed Entity
# ...

# %%
template[["#Question Ref.", "Reporting Requirement", "Definitions", "Department", "answer"]]
# Out:
#     #Question Ref.                              Reporting Requirement  \
# 0              1.1  Corporate Identity Number (CIN) of the Listed ...
# 1              1.2                          Name of the Listed Entity
# 2              1.3                              Year of incorporation
# 3              1.4                          Registered office address
# 4              1.5                                  Corporate address
# ..             ...                                                ...
# 141           11.7  Channels / platforms where information on prod...
# 142           11.8  Steps taken to inform and educate consumers ab...
# 143           11.9  Mechanisms in place to inform consumers of any...
# 144           11.1  Does the entity display product information on...
# 145  11.11 / 1.4.8  Provide the following information relating to ...
#
#                                            Definitions        Department  \
# ...
